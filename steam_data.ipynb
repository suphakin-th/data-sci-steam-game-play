# %%
import pandas as pd
import numpy as np

import json

# %%
steam_game_appid = json.load(open('./steam_data_sci/steam_appid.json'))
print(steam_game_appid)
steam_game_appid = steam_game_appid['applist']['apps']
steam_game_appid
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [{'appid': 1941401, 'name': ''},
#  {'appid': 2170321, 'name': ''},
#  {'appid': 1825161, 'name': ''},
#  {'appid': 1897482, 'name': ''},
#  {'appid': 2112761, 'name': ''},
#  {'appid': 1829051, 'name': ''},
#  {'appid': 1808781, 'name': ''},
#  {'appid': 1983382, 'name': ''},
#  {'appid': 1828741, 'name': ''},
#  {'appid': 216938, 'name': 'Pieterw test app76 ( 216938 )'},
#  {'appid': 660010, 'name': 'test2'},
#  {'appid': 660130, 'name': 'test3'},
#  {'appid': 1118314, 'name': ''},
#  {'appid': 1275822, 'name': ''},
#  {'appid': 1343832, 'name': ''},
#  {'appid': 662172, 'name': ''},
#  {'appid': 1360782, 'name': ''},
# ...

# %% [markdown]
# # Clean data

# %%
appid_df = pd.DataFrame(steam_game_appid)
appid_df = appid_df[appid_df['name'].str.len() > 0]
appid_df
# Out:
#           appid                                    name
# 9        216938           Pieterw test app76 ( 216938 )
# 10       660010                                   test2
# 11       660130                                   test3
# 32      1826300  SOTANO - Mystery Escape Room Adventure
# 33      1826310                     Porcelain Mask Demo
# ...         ...                                     ...
# 154793   258550                   Rust Dedicated Server
# 154794  1502190                              From Space
# 154795  1470390                           City of Beats
# 154796  1460790                     Bartender Simulator
# 154797  1948800      Yi Xian: The Cultivation Card Game
#
# [154769 rows x 2 columns]

# %%
steam_game_details = pd.read_csv('./steam_data_sci/steam_games.csv')
steam_game_details[['types', 'name', 'release_date', 'url', 'developer']]
# Out:
#       types                                               name  release_date  \
# 0       app                                               DOOM  May 12, 2016
# 1       app                      PLAYERUNKNOWN'S BATTLEGROUNDS  Dec 21, 2017
# 2       app                                         BATTLETECH  Apr 24, 2018
# 3       app                                               DayZ  Dec 13, 2018
# 4       app                                         EVE Online   May 6, 2003
# ...     ...                                                ...           ...
# 40828   app  Rocksmith® 2014 Edition – Remastered – Sabaton...  Feb 12, 2019
# 40829   app  Rocksmith® 2014 Edition – Remastered – Stone T...   Feb 5, 2019
# 40830   app  Fantasy Grounds - Quests of Doom 4: A Midnight...  Jul 31, 2018
# 40831   app                       Mega Man X5 Sound Collection  Jul 24, 2018
# 40832   app                                   Stories In Stone   Aug 8, 2018
#
# ...
